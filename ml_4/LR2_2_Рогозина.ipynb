# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0y1eeetVIeftVB2mSPaS")
project = rf.workspace("colaftextes").project("segmonto")
version = project.version(32)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 23.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Segmonto-32 in yolov8:: 100%|██████████| 10480/10480 [00:06<00:00, 1615.55it/s]

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.2 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8s.pt")

# %% [markdown]
# ## 10 - так как я загнусь 100 ждать

# %%
model.train(data="/content/Segmonto-32/data.yaml", epochs=10, optimizer= 'Adam', patience=10,
            cos_lr=True, lr0=1e-3, plots=True)
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
Image('/content/runs/detect/train/results.png')

# %%
import pandas as pd

df = pd.read_csv('/content/runs/detect/train/results.csv')
df
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   154.096         1.41782         2.50933         1.25662
# 1      2   294.202         1.23930         1.94772         1.16114
# 2      3   433.547         1.19386         1.80060         1.13415
# 3      4   572.094         1.14724         1.71616         1.11557
# 4      5   709.479         1.09185         1.58853         1.08720
# 5      6   845.978         1.04801         1.50508         1.06400
# 6      7   982.059         1.00669         1.40595         1.04672
# 7      8  1119.940         0.97825         1.34204         1.02902
# 8      9  1256.780         0.94822         1.26445         1.01278
# 9     10  1393.100         0.93303         1.22863         1.01005
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.70283            0.13824           0.11769
# 1               0.53722            0.14798           0.13770
# ...

# %%
Image('/content/runs/detect/train/train_batch0.jpg')

# %%
metrics = model.val(data="/content/Segmonto-32/data.yaml", imgsz=640)
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1977.1±759.2 MB/s, size: 335.6 KB)
# val: Scanning /content/Segmonto-32/valid/labels.cache... 620 images, 16 backgrounds, 0 corrupt: 100%|██████████| 620/620 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 208, len(boxes) = 7339. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 39/39 [00:19<00:00,  2.01it/s]
#                    all        620       7339      0.529      0.322       0.32      0.214
#      AdvertisementZone          8         19      0.262      0.211      0.115     0.0713
# ...

# %%
Image('/content/runs/detect/val2/confusion_matrix_normalized.png')

# %%
Image('/content/runs/detect/val2/PR_curve.png')

# %%
model.predict('/content/word_example.jpg', save=True, imgsz=640, conf=0.1)
# Out:
# image 1/1 /content/word_example.jpg: 640x640 1 GraphicZone, 1 GraphicZone-FigDesc, 1 GraphicZone-Head, 2 MainZone-Heads, 7 NumberingZones, 9 TableZones, 16.6ms
# Speed: 2.6ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train25
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
Image('/content/runs/detect/train25/word_example.jpg')

# %%
model.predict('/content/word_example2.jpg', save=True, imgsz=340, conf=0.1)
# Out:
# WARNING ⚠️ imgsz=[340] must be multiple of max stride 32, updating to [352]
# image 1/1 /content/word_example2.jpg: 352x352 1 DropCapitalZone, 2 GraphicZones, 2 MainZone-Heads, 3 MainZone-Ps, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 352)
# Results saved to runs/detect/train27
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
Image('/content/runs/detect/train27/word_example2.jpg')

# %% [markdown]
# # Вывод: детекцию можно считать достаточно корректной, recall низкий, по изображениям видно, что разметка похожа на верную
